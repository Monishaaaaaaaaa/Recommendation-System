# %% [markdown]
# ### Data Loading and preprocessing

# %%
import pandas as pd

df= pd.read_csv(r"C:\Users\USER\Downloads\anime.csv")
df.head()
# Out:
#    anime_id                              name  \
# 0     32281                    Kimi no Na wa.
# 1      5114  Fullmetal Alchemist: Brotherhood
# 2     28977                          Gintama°
# 3      9253                       Steins;Gate
# 4      9969                     Gintama&#039;
#
#                                                genre   type episodes  rating  \
# 0               Drama, Romance, School, Supernatural  Movie        1    9.37
# 1  Action, Adventure, Drama, Fantasy, Magic, Mili...     TV       64    9.26
# 2  Action, Comedy, Historical, Parody, Samurai, S...     TV       51    9.25
# 3                                   Sci-Fi, Thriller     TV       24    9.17
# 4  Action, Comedy, Historical, Parody, Samurai, S...     TV       51    9.16
#
#    members
# 0   200630
# 1   793665
# 2   114262
# 3   673572
# 4   151266

# %%
df.tail()
# Out:
#        anime_id                                               name   genre  \
# 12289      9316       Toushindai My Lover: Minami tai Mecha-Minami  Hentai
# 12290      5543                                        Under World  Hentai
# 12291      5621                     Violence Gekiga David no Hoshi  Hentai
# 12292      6133  Violence Gekiga Shin David no Hoshi: Inma Dens...  Hentai
# 12293     26081                   Yasuji no Pornorama: Yacchimae!!  Hentai
#
#         type episodes  rating  members
# 12289    OVA        1    4.15      211
# 12290    OVA        1    4.28      183
# 12291    OVA        4    4.88      219
# 12292    OVA        1    4.98      175
# 12293  Movie        1    5.46      142

# %%
#Dimension
df.shape
# Out:
# (12294, 7)

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 12294 entries, 0 to 12293
# Data columns (total 7 columns):
#  #   Column    Non-Null Count  Dtype
# ---  ------    --------------  -----
#  0   anime_id  12294 non-null  int64
#  1   name      12294 non-null  object
#  2   genre     12232 non-null  object
#  3   type      12269 non-null  object
#  4   episodes  12294 non-null  object
#  5   rating    12064 non-null  float64
#  6   members   12294 non-null  int64
# dtypes: float64(1), int64(2), object(4)
# memory usage: 672.5+ KB

# %%
df.describe()
# Out:
#            anime_id        rating       members
# count  12294.000000  12064.000000  1.229400e+04
# mean   14058.221653      6.473902  1.807134e+04
# std    11455.294701      1.026746  5.482068e+04
# min        1.000000      1.670000  5.000000e+00
# 25%     3484.250000      5.880000  2.250000e+02
# 50%    10260.500000      6.570000  1.550000e+03
# 75%    24794.500000      7.180000  9.437000e+03
# max    34527.000000     10.000000  1.013917e+06

# %%
df.dtypes
# Out:
# anime_id      int64
# name         object
# genre        object
# type         object
# episodes     object
# rating      float64
# members       int64
# dtype: object

# %%
df.duplicated().sum()
# Out:
# np.int64(0)

# %%
df.isnull().sum()
# Out:
# anime_id      0
# name          0
# genre        62
# type         25
# episodes      0
# rating      230
# members       0
# dtype: int64

# %%
#Filling null values
df['genre'].fillna(df['genre'].mode()[0], inplace=True) #Picks the first mode value
df['type'].fillna(df['type'].mode()[0], inplace=True)
df['rating'].fillna(0, inplace=True)
# Out:
# C:\Users\USER\AppData\Local\Temp\ipykernel_12528\3218946982.py:1: FutureWarning: A value is trying to be set on a copy of a DataFrame or Series through chained assignment using an inplace method.
# The behavior will change in pandas 3.0. This inplace method will never work because the intermediate object on which we are setting values always behaves as a copy.
#
# For example, when doing 'df[col].method(value, inplace=True)', try using 'df.method({col: value}, inplace=True)' or df[col] = df[col].method(value) instead, to perform the operation inplace on the original object.
#
#
#   df['genre'].fillna(df['genre'].mode()[0], inplace=True) #Picks the first mode value
# C:\Users\USER\AppData\Local\Temp\ipykernel_12528\3218946982.py:2: FutureWarning: A value is trying to be set on a copy of a DataFrame or Series through chained assignment using an inplace method.
# ...

# %%
# Replace 'Unknown' with NaN
import numpy as np

df['episodes'] = df['episodes'].replace('Unknown', np.nan)

# Convert to numeric
df['episodes'] = pd.to_numeric(df['episodes'], errors='coerce')

# Fill missing values with median
df['episodes'].fillna(df['episodes'].median(), inplace=True)
# Out:
# C:\Users\USER\AppData\Local\Temp\ipykernel_12528\2998355492.py:10: FutureWarning: A value is trying to be set on a copy of a DataFrame or Series through chained assignment using an inplace method.
# The behavior will change in pandas 3.0. This inplace method will never work because the intermediate object on which we are setting values always behaves as a copy.
#
# For example, when doing 'df[col].method(value, inplace=True)', try using 'df.method({col: value}, inplace=True)' or df[col] = df[col].method(value) instead, to perform the operation inplace on the original object.
#
#
#   df['episodes'].fillna(df['episodes'].median(), inplace=True)

# %%
df.isnull().sum()
# Out:
# anime_id    0
# name        0
# genre       0
# type        0
# episodes    0
# rating      0
# members     0
# dtype: int64

# %%
df.columns
# Out:
# Index(['anime_id', 'name', 'genre', 'type', 'episodes', 'rating', 'members'], dtype='object')

# %%
# Split genres into list
df['genre'] = df['genre'].apply(lambda x: x.split(',') if isinstance(x,str) else [])

# %%
# Feature Extraction
# One-hot encode genres
from sklearn.preprocessing import MinMaxScaler, MultiLabelBinarizer

mlb = MultiLabelBinarizer()
genre_features = mlb.fit_transform(df['genre'])

# %%
# Normalize numerical features
scaler = MinMaxScaler()
numerical_features = scaler.fit_transform(df[['rating','episodes','members']])

# %%
# Combine features
features = np.hstack([genre_features, numerical_features]) #Horizontal stack -concatenation

# %%
#Compute Cosine Similarity

from sklearn.metrics.pairwise import cosine_similarity

similarity_matrix = cosine_similarity(features)

# %%
#Recommendation Function
def recommend_anime(title, top_n=10):
    if title not in df['name'].values:
        return f"Anime '{title}' not found in dataset"
    idx = df[df['name'] == title].index[0]
    sim_scores = list(enumerate(similarity_matrix[idx]))
    sim_scores = sorted(sim_scores, key=lambda x: x[1], reverse=True)
    sim_scores = sim_scores[1:top_n+1] # exclude the anime itself
    recommended = [df.iloc[i[0]]['name'] for i in sim_scores]
    return recommended

# %%
# Test Recommendations
recommendations = recommend_anime('Gintama°', top_n=10)
print('Recommended anime for Kimi no Na wa.:')
for i, anime in enumerate(recommendations,1):
    print(f'{i}. {anime}')
# Out:
# Recommended anime for Kimi no Na wa.:
# 1. Gintama&#039;
# 2. Gintama&#039;: Enchousen
# 3. Gintama Movie: Kanketsu-hen - Yorozuya yo Eien Nare
# 4. Gintama Movie: Shinyaku Benizakura-hen
# 5. Gintama: Yorinuki Gintama-san on Theater 2D
# 6. Gintama: Shinyaku Benizakura-hen
# 7. Gintama: Jump Festa 2014 Special
# 8. Gintama
# 9. Gintama (2017)
# 10. Gintama: Nanigoto mo Saiyo ga Kanjin nano de Tasho Senobisuru Kurai ga Choudoyoi

# %% [raw]
# In this project, I built an anime recommendation system using a content-based approach. I first preprocessed the dataset by handling missing values, converting unknown episodes to numeric, and cleaning the genre column. I then extracted features by one-hot encoding the multi-label genres and normalizing numerical features like ratings, episodes, and community members. These features were combined into feature vectors, and cosine similarity was used to measure similarity between anime. Finally, I implemented a recommendation function that returns the top 10 most similar anime for a given title, providing relevant suggestions based on structured metadata.

# %% [raw]
# INTEVIEW QUESTIONS
#
# 1. What is collaborative filtering, and how does it work?
# Collaborative filtering is a recommendation technique used to predict a user’s preferences by analyzing the behavior and interactions of multiple users. It is based on the idea that users who have shown similar preferences in the past are likely to have similar interests in the future. The system collects user–item interaction data such as ratings, purchases, or clicks and identifies patterns within this data. Using these patterns, it predicts how much a user may like an unseen item and recommends items with the highest predicted preference. Collaborative filtering does not require detailed information about item features, making it flexible and widely applicable in recommendation systems.
#
# 2. Explain the difference between user-based and item-based collaborative filtering.
# User-based collaborative filtering works by identifying users who are similar to a target user based on their past interactions and then recommending items that those similar users have liked. The main idea is that people with similar tastes will prefer similar items. Item-based collaborative filtering, on the other hand, focuses on finding similarities between items rather than users. It recommends items that are similar to those the user has already interacted with. While user-based methods can become inefficient as the number of users grows and as user preferences change, item-based methods are generally more scalable and stable, which makes them more suitable for large-scale real-world recommendation systems.
